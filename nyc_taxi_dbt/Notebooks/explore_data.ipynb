# %%
import duckdb

# %%
conn = duckdb.connect()

# %%
# How many rows?
print(conn.execute("""
    SELECT COUNT(*) 
    FROM read_parquet('C:/Users/skhan9/de-learning-journey/nyc_taxi_dbt/data/yellow_tripdata_2025-01.parquet')
""").fetchall())
# Out:
# [(3475226,)]

# %%
# What columns exist?
print(conn.execute("""
    DESCRIBE SELECT * 
    FROM read_parquet('C:/Users/skhan9/de-learning-journey/nyc_taxi_dbt/data/yellow_tripdata_2025-01.parquet')
""").fetchall())
# Out:
# [('VendorID', 'INTEGER', 'YES', None, None, None), ('tpep_pickup_datetime', 'TIMESTAMP', 'YES', None, None, None), ('tpep_dropoff_datetime', 'TIMESTAMP', 'YES', None, None, None), ('passenger_count', 'BIGINT', 'YES', None, None, None), ('trip_distance', 'DOUBLE', 'YES', None, None, None), ('RatecodeID', 'BIGINT', 'YES', None, None, None), ('store_and_fwd_flag', 'VARCHAR', 'YES', None, None, None), ('PULocationID', 'INTEGER', 'YES', None, None, None), ('DOLocationID', 'INTEGER', 'YES', None, None, None), ('payment_type', 'BIGINT', 'YES', None, None, None), ('fare_amount', 'DOUBLE', 'YES', None, None, None), ('extra', 'DOUBLE', 'YES', None, None, None), ('mta_tax', 'DOUBLE', 'YES', None, None, None), ('tip_amount', 'DOUBLE', 'YES', None, None, None), ('tolls_amount', 'DOUBLE', 'YES', None, None, None), ('improvement_surcharge', 'DOUBLE', 'YES', None, None, None), ('total_amount', 'DOUBLE', 'YES', None, None, None), ('congestion_surcharge', 'DOUBLE', 'YES', None, None, None), ('Airport_
# ...

# %%
# Sample 5 rows
print(conn.execute("""
    SELECT * 
    FROM read_parquet('C:/Users/skhan9/de-learning-journey/nyc_taxi_dbt/data/yellow_tripdata_2025-01.parquet')
    LIMIT 5
""").fetchall())
# Out:
# [(1, datetime.datetime(2025, 1, 1, 0, 18, 38), datetime.datetime(2025, 1, 1, 0, 26, 59), 1, 1.6, 1, 'N', 229, 237, 1, 10.0, 3.5, 0.5, 3.0, 0.0, 1.0, 18.0, 2.5, 0.0, 0.0), (1, datetime.datetime(2025, 1, 1, 0, 32, 40), datetime.datetime(2025, 1, 1, 0, 35, 13), 1, 0.5, 1, 'N', 236, 237, 1, 5.1, 3.5, 0.5, 2.02, 0.0, 1.0, 12.12, 2.5, 0.0, 0.0), (1, datetime.datetime(2025, 1, 1, 0, 44, 4), datetime.datetime(2025, 1, 1, 0, 46, 1), 1, 0.6, 1, 'N', 141, 141, 1, 5.1, 3.5, 0.5, 2.0, 0.0, 1.0, 12.1, 2.5, 0.0, 0.0), (2, datetime.datetime(2025, 1, 1, 0, 14, 27), datetime.datetime(2025, 1, 1, 0, 20, 1), 3, 0.52, 1, 'N', 244, 244, 2, 7.2, 1.0, 0.5, 0.0, 0.0, 1.0, 9.7, 0.0, 0.0, 0.0), (2, datetime.datetime(2025, 1, 1, 0, 21, 34), datetime.datetime(2025, 1, 1, 0, 25, 6), 3, 0.66, 1, 'N', 244, 116, 2, 5.8, 1.0, 0.5, 0.0, 0.0, 1.0, 8.3, 0.0, 0.0, 0.0)]

# %%
import duckdb
import pandas as pd

conn = duckdb.connect()

df = conn.execute("""
    SELECT *
    FROM read_parquet('C:/Users/skhan9/de-learning-journey/nyc_taxi_dbt/data/yellow_tripdata_2025-01.parquet')
    LIMIT 5
""").df()

print(df.columns.tolist())
print(df.head())
# Out:
# ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'Airport_fee', 'cbd_congestion_fee']
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59                1
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13                1
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01                1
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01                3
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06                3
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.60           1                  N           229           237
# ...
